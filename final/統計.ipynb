# %%
champions_dict = {
    "曼联": ["2012/2013", "2010/2011", "2008/2009", "2007/2008", "2006/2007", "2002/2003", "2000/2001", "1999/2000", "1998/1999", "1996/1997", "1995/1996", "1993/1994", "1992/1993", "1966/1967", "1964/1965", "1956/1957", "1955/1956", "1951/1952", "1910/1911", "1907/1908"],
    "利物浦": ["2019/2020", "1989/1990", "1987/1988", "1985/1986", "1983/1984", "1982/1983", "1981/1982", "1979/1980", "1978/1979", "1976/1977", "1975/1976", "1972/1973", "1965/1966", "1963/1964", "1946/1947", "1922/1923", "1921/1922", "1905/1906", "1900/1901"],
    "阿森纳": ["2003/2004", "2001/2002", "1997/1998", "1990/1991", "1988/1989", "1970/1971", "1952/1953", "1947/1948", "1937/1938", "1934/1935", "1933/1934", "1932/1933", "1930/1931"],
    "埃弗顿": ["1986/1987", "1984/1985", "1969/1970", "1962/1963", "1938/1939", "1931/1932", "1927/1928", "1914/1915", "1890/1891"],
    "曼城": ["2022/2023", "2021/2022", "2020/2021", "2018/2019", "2017/2018", "2013/2014", "2011/2012", "1967/1968", "1936/1937"],
    "阿斯顿维拉": ["1980/1981","1909/1910","1899/1900","1898/1899","1896/1897","1895/1896","1893/1894"],
    "切尔西": ["2016/2017","2014/2015","2009/2010","2005/2006","2004/2005","1954/1955"],
    "桑德兰": ["1935/1936","1912/1913","1901/1902","1894/1895","1892/1893","1891/1892"],
    "谢菲尔德星期三": ["1929/1930","1928/1929","1903/1904","1902/1903"],
    "纽卡斯尔联": ["1926/1927","1908/1909","1906/1907","1904/1905"],
    "布莱顿": ["1994/1995","1913/1914","1911/1912"],
    "利兹联": ["1991/1992","1973/1974","1968/1969"],
    "狼队": ["1958/1959","1957/1958","1953/1954"],
    "哈德斯菲尔德镇": ["1925/1926","1924/1925","1923/1924"],
    "德比郡": ["1974/1975","1971/1972"],
    "托特纳姆热刺": ["1960/1961","1950/1951"],
    "伯恩利": ["1959/1960","1920/1921"],
    "伯恩茅斯": ["1949/1950","1948/1949"],
    "普雷斯顿": ["1889/1990","1888/1889"],
    "莱斯特城": ["2015/2016"],
    "诺丁汉森林": ["1977/1978"],
    "伊普斯威奇": ["1961/1962"],
    "西布罗姆维奇": ["1919/1920"],
    "谢菲尔德联队": ["1897/1898"],
}

# 初始化两个字典，用于存储2000年前后的夺冠次数
pre_2000_champions_count = {}
post_2000_champions_count = {}

# 遍历字典，根据年份计算夺冠次数
for team, years in champions_dict.items():
    # 初始化计数器
    pre_2000_count = 0
    post_2000_count = 0
    for year in years:
        # 分割年份字符串并取得起始年
        start_year = int(year.split('/')[0])
        # 根据年份更新计数器
        if start_year >= 2000:
            post_2000_count += 1
        else:
            pre_2000_count += 1
    # 将计数器结果存储到对应的字典中
    pre_2000_champions_count[team] = pre_2000_count
    post_2000_champions_count[team] = post_2000_count

# 打印结果
print("2000年后各队夺冠次数:")
for team, count in post_2000_champions_count.items():
    print(f"{team}: {count}")

print("\n2000年前各队夺冠次数:")
for team, count in pre_2000_champions_count.items():
    print(f"{team}: {count}")
# Out:
# 2000年后各队夺冠次数:
# 曼联: 7
# 利物浦: 1
# 阿森纳: 2
# 埃弗顿: 0
# 曼城: 7
# 阿斯顿维拉: 0
# 切尔西: 5
# 桑德兰: 0
# 谢菲尔德星期三: 0
# 纽卡斯尔联: 0
# 布莱顿: 0
# 利兹联: 0
# 狼队: 0
# 哈德斯菲尔德镇: 0
# 德比郡: 0
# 托特纳姆热刺: 0
# 伯恩利: 0
# 伯恩茅斯: 0
# 普雷斯顿: 0
# 莱斯特城: 1
# 诺丁汉森林: 0
# 伊普斯威奇: 0
# 西布罗姆维奇: 0
# 谢菲尔德联队: 0
#
# 2000年前各队夺冠次数:
# 曼联: 13
# 利物浦: 18
# 阿森纳: 11
# 埃弗顿: 9
# 曼城: 2
# 阿斯顿维拉: 7
# 切尔西: 1
# 桑德兰: 6
# 谢菲尔德星期三: 4
# 纽卡斯尔联: 4
# 布莱顿: 3
# 利兹联: 3
# 狼队: 3
# 哈德斯菲尔德镇: 3
# 德比郡: 2
# 托特纳姆热刺: 2
# 伯恩利: 2
# 伯恩茅斯: 2
# 普雷斯顿: 2
# 莱斯特城: 0
# 诺丁汉森林: 1
# 伊普斯威奇: 1
# 西布罗姆维奇: 1
# 谢菲尔德联队: 1
